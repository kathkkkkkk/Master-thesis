# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf 

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.datasets import mnist
from sklearn.model_selection import train_test_split

# %%
# import data 
DATASET_SIZE = 70000
TRAIN_RATIO = 0.7
VALIDATION_RATIO = 0.2
TEST_RATIO = 0.1

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x = np.concatenate([x_train, x_test])
y = np.concatenate([y_train, y_test])

x_train_orig, x_valid_orig, y_train_orig, y_valid_orig = train_test_split(x, y, test_size=(1-TRAIN_RATIO))
x_valid_orig, x_test_orig, y_valid_orig, y_test_orig = train_test_split(x_valid_orig, y_valid_orig, test_size=((TEST_RATIO/(VALIDATION_RATIO+TEST_RATIO))))

# %%
# reshape 
x_train = x_train_orig.reshape(x_train_orig.shape[0], -1).astype('float32')/255.
y_train = y_train_orig

x_valid = x_valid_orig.reshape(x_valid_orig.shape[0], -1).astype('float32')/255.
y_valid = y_valid_orig

x_test = x_test_orig.reshape(x_test_orig.shape[0], -1).astype('float32')/255.
y_test = y_test_orig

# %%
# define model 
# Neural network 

input_size = 784
m_size = 2**5
hidden_size = 128
output_size = 10

# encoding 
input_img = tf.keras.Input(shape=(input_size,))


# middle layer 
m_layer = Dense(m_size, activation='relu')(input_img) # cos 
    #m_layer = Dense(m_size, activation='relu')(h2_layer)

output_img = Dense(output_size, activation='sigmoid')(m_layer) # linear 

model = Model(input_img, output_img)

print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 32)                25120
#
#  dense_1 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# training setting 
model.compile(loss='sparse_categorical_crossentropy', optimizer='SGD', 
              metrics=['accuracy'])

M = 100
seed = 1
tf.random.set_seed(seed)
history = model.fit(x=x_train, y=y_train_orig, validation_data = (x_valid, y_valid), 
          epochs=M, batch_size=32, verbose=2)
# Out:
# Epoch 1/100
# 1532/1532 - 1s - loss: 0.7678 - accuracy: 0.8000 - val_loss: 0.4244 - val_accuracy: 0.8864 - 1s/epoch - 864us/step
# Epoch 2/100
# 1532/1532 - 1s - loss: 0.3737 - accuracy: 0.8958 - val_loss: 0.3468 - val_accuracy: 0.9019 - 962ms/epoch - 628us/step
# Epoch 3/100
# 1532/1532 - 1s - loss: 0.3230 - accuracy: 0.9087 - val_loss: 0.3221 - val_accuracy: 0.9091 - 927ms/epoch - 605us/step
# Epoch 4/100
# 1532/1532 - 1s - loss: 0.2961 - accuracy: 0.9159 - val_loss: 0.2990 - val_accuracy: 0.9164 - 950ms/epoch - 620us/step
# Epoch 5/100
# 1532/1532 - 1s - loss: 0.2768 - accuracy: 0.9224 - val_loss: 0.2804 - val_accuracy: 0.9202 - 944ms/epoch - 617us/step
# Epoch 6/100
# 1532/1532 - 1s - loss: 0.2620 - accuracy: 0.9259 - val_loss: 0.2668 - val_accuracy: 0.9226 - 940ms/epoch - 614us/step
# Epoch 7/100
# 1532/1532 - 1s - loss: 0.2489 - accuracy: 0.9301 - val_loss: 0.2602 - val_accuracy: 0.9250 - 923ms/epoch - 603us/step
# Epoch 8/100
# 1532/1532 - 1s - loss: 0.2380 - accuracy: 0.9337 - val_loss: 0.2480 - val_accuracy: 0.9293 - 925ms/epoch - 604us/step
# Epoch 9/100
# 1532/1532 - 1s - loss: 0.2281 - accuracy: 0.9364 - val_loss: 0.2398 - val_accuracy: 0.9324 - 925ms/epoch - 604us/step
# Epoch 10/100
# 1532/1532 - 1s - loss: 0.2191 - accuracy: 0.9388 - val_loss: 0.2332 - val_accuracy: 0.9337 - 940ms/epoch - 613us/step
# Epoch 11/100
# 1532/1532 - 1s - loss: 0.2107 - accuracy: 0.9407 - val_loss: 0.2270 - val_accuracy: 0.9357 - 951ms/epoch - 621us/step
# Epoch 12/100
# 1532/1532 - 1s - loss: 0.2033 - accuracy: 0.9430 - val_loss: 0.2198 - val_accuracy: 0.9376 - 932ms/epoch - 608us/step
# Epoch 13/100
# 1532/1532 - 1s - loss: 0.1965 - accuracy: 0.9456 - val_loss: 0.2164 - val_accuracy: 0.9384 - 928ms/epoch - 606us/step
# Epoch 14/100
# 1532/1532 - 1s - loss: 0.1904 - accuracy: 0.9469 - val_loss: 0.2090 - val_accuracy: 0.9419 - 936ms/epoch - 611us/step
# Epoch 15/100
# 1532/1532 - 1s - loss: 0.1843 - accuracy: 0.9482 - val_loss: 0.2038 - val_accuracy: 0.9421 - 956ms/epoch - 624us/step
# Epoch 16/100
# 1532/1532 - 1s - loss: 0.1788 - accuracy: 0.9503 - val_loss: 0.2014 - val_accuracy: 0.9419 - 930ms/epoch - 607us/step
# Epoch 17/100
# 1532/1532 - 1s - loss: 0.1735 - accuracy: 0.9520 - val_loss: 0.1951 - val_accuracy: 0.9446 - 948ms/epoch - 619us/step
# Epoch 18/100
# 1532/1532 - 1s - loss: 0.1687 - accuracy: 0.9528 - val_loss: 0.1924 - val_accuracy: 0.9438 - 949ms/epoch - 620us/step
# Epoch 19/100
# 1532/1532 - 1s - loss: 0.1643 - accuracy: 0.9544 - val_loss: 0.1878 - val_accuracy: 0.9455 - 948ms/epoch - 619us/step
# Epoch 20/100
# 1532/1532 - 1s - loss: 0.1601 - accuracy: 0.9552 - val_loss: 0.1838 - val_accuracy: 0.9468 - 966ms/epoch - 631us/step
# Epoch 21/100
# 1532/1532 - 1s - loss: 0.1557 - accuracy: 0.9566 - val_loss: 0.1814 - val_accuracy: 0.9468 - 980ms/epoch - 639us/step
# Epoch 22/100
# 1532/1532 - 1s - loss: 0.1520 - accuracy: 0.9578 - val_loss: 0.1782 - val_accuracy: 0.9485 - 943ms/epoch - 616us/step
# Epoch 23/100
# 1532/1532 - 1s - loss: 0.1483 - accuracy: 0.9588 - val_loss: 0.1746 - val_accuracy: 0.9502 - 940ms/epoch - 613us/step
# Epoch 24/100
# 1532/1532 - 1s - loss: 0.1447 - accuracy: 0.9598 - val_loss: 0.1734 - val_accuracy: 0.9495 - 963ms/epoch - 628us/step
# Epoch 25/100
# 1532/1532 - 1s - loss: 0.1416 - accuracy: 0.9608 - val_loss: 0.1693 - val_accuracy: 0.9509 - 1s/epoch - 662us/step
# Epoch 26/100
# 1532/1532 - 1s - loss: 0.1385 - accuracy: 0.9608 - val_loss: 0.1702 - val_accuracy: 0.9502 - 953ms/epoch - 622us/step
# Epoch 27/100
# 1532/1532 - 1s - loss: 0.1354 - accuracy: 0.9617 - val_loss: 0.1665 - val_accuracy: 0.9512 - 942ms/epoch - 615us/step
# Epoch 28/100
# 1532/1532 - 1s - loss: 0.1327 - accuracy: 0.9628 - val_loss: 0.1653 - val_accuracy: 0.9518 - 947ms/epoch - 618us/step
# Epoch 29/100
# 1532/1532 - 1s - loss: 0.1298 - accuracy: 0.9637 - val_loss: 0.1616 - val_accuracy: 0.9532 - 1s/epoch - 658us/step
# Epoch 30/100
# 1532/1532 - 1s - loss: 0.1274 - accuracy: 0.9640 - val_loss: 0.1593 - val_accuracy: 0.9529 - 916ms/epoch - 598us/step
# Epoch 31/100
# 1532/1532 - 1s - loss: 0.1248 - accuracy: 0.9648 - val_loss: 0.1600 - val_accuracy: 0.9534 - 920ms/epoch - 600us/step
# Epoch 32/100
# 1532/1532 - 1s - loss: 0.1224 - accuracy: 0.9655 - val_loss: 0.1559 - val_accuracy: 0.9535 - 922ms/epoch - 602us/step
# Epoch 33/100
# 1532/1532 - 1s - loss: 0.1199 - accuracy: 0.9666 - val_loss: 0.1544 - val_accuracy: 0.9556 - 928ms/epoch - 606us/step
# Epoch 34/100
# 1532/1532 - 1s - loss: 0.1178 - accuracy: 0.9664 - val_loss: 0.1549 - val_accuracy: 0.9541 - 914ms/epoch - 597us/step
# Epoch 35/100
# 1532/1532 - 1s - loss: 0.1158 - accuracy: 0.9677 - val_loss: 0.1527 - val_accuracy: 0.9549 - 925ms/epoch - 604us/step
# Epoch 36/100
# 1532/1532 - 1s - loss: 0.1138 - accuracy: 0.9683 - val_loss: 0.1507 - val_accuracy: 0.9558 - 922ms/epoch - 602us/step
# Epoch 37/100
# 1532/1532 - 1s - loss: 0.1119 - accuracy: 0.9683 - val_loss: 0.1492 - val_accuracy: 0.9565 - 912ms/epoch - 596us/step
# Epoch 38/100
# 1532/1532 - 1s - loss: 0.1100 - accuracy: 0.9692 - val_loss: 0.1481 - val_accuracy: 0.9574 - 912ms/epoch - 596us/step
# Epoch 39/100
# 1532/1532 - 1s - loss: 0.1082 - accuracy: 0.9694 - val_loss: 0.1494 - val_accuracy: 0.9558 - 913ms/epoch - 596us/step
# Epoch 40/100
# 1532/1532 - 1s - loss: 0.1064 - accuracy: 0.9702 - val_loss: 0.1456 - val_accuracy: 0.9574 - 912ms/epoch - 595us/step
# Epoch 41/100
# 1532/1532 - 1s - loss: 0.1048 - accuracy: 0.9707 - val_loss: 0.1449 - val_accuracy: 0.9574 - 911ms/epoch - 595us/step
# Epoch 42/100
# 1532/1532 - 1s - loss: 0.1032 - accuracy: 0.9708 - val_loss: 0.1438 - val_accuracy: 0.9589 - 914ms/epoch - 596us/step
# Epoch 43/100
# 1532/1532 - 1s - loss: 0.1014 - accuracy: 0.9714 - val_loss: 0.1446 - val_accuracy: 0.9581 - 921ms/epoch - 601us/step
# Epoch 44/100
# 1532/1532 - 1s - loss: 0.0999 - accuracy: 0.9721 - val_loss: 0.1436 - val_accuracy: 0.9582 - 1s/epoch - 681us/step
# Epoch 45/100
# 1532/1532 - 1s - loss: 0.0986 - accuracy: 0.9726 - val_loss: 0.1430 - val_accuracy: 0.9574 - 1s/epoch - 713us/step
# Epoch 46/100
# 1532/1532 - 1s - loss: 0.0973 - accuracy: 0.9729 - val_loss: 0.1409 - val_accuracy: 0.9579 - 944ms/epoch - 616us/step
# Epoch 47/100
# 1532/1532 - 1s - loss: 0.0958 - accuracy: 0.9729 - val_loss: 0.1426 - val_accuracy: 0.9586 - 1s/epoch - 655us/step
# Epoch 48/100
# 1532/1532 - 1s - loss: 0.0944 - accuracy: 0.9736 - val_loss: 0.1379 - val_accuracy: 0.9596 - 920ms/epoch - 600us/step
# Epoch 49/100
# 1532/1532 - 1s - loss: 0.0932 - accuracy: 0.9739 - val_loss: 0.1377 - val_accuracy: 0.9604 - 1s/epoch - 790us/step
# Epoch 50/100
# 1532/1532 - 1s - loss: 0.0918 - accuracy: 0.9747 - val_loss: 0.1384 - val_accuracy: 0.9598 - 996ms/epoch - 650us/step
# Epoch 51/100
# 1532/1532 - 1s - loss: 0.0907 - accuracy: 0.9749 - val_loss: 0.1377 - val_accuracy: 0.9590 - 930ms/epoch - 607us/step
# Epoch 52/100
# 1532/1532 - 1s - loss: 0.0895 - accuracy: 0.9753 - val_loss: 0.1363 - val_accuracy: 0.9592 - 921ms/epoch - 601us/step
# Epoch 53/100
# 1532/1532 - 1s - loss: 0.0883 - accuracy: 0.9750 - val_loss: 0.1363 - val_accuracy: 0.9602 - 947ms/epoch - 618us/step
# Epoch 54/100
# 1532/1532 - 1s - loss: 0.0871 - accuracy: 0.9762 - val_loss: 0.1365 - val_accuracy: 0.9601 - 953ms/epoch - 622us/step
# Epoch 55/100
# 1532/1532 - 1s - loss: 0.0860 - accuracy: 0.9762 - val_loss: 0.1346 - val_accuracy: 0.9609 - 952ms/epoch - 621us/step
# Epoch 56/100
# 1532/1532 - 1s - loss: 0.0848 - accuracy: 0.9769 - val_loss: 0.1349 - val_accuracy: 0.9607 - 933ms/epoch - 609us/step
# Epoch 57/100
# 1532/1532 - 1s - loss: 0.0836 - accuracy: 0.9775 - val_loss: 0.1354 - val_accuracy: 0.9605 - 965ms/epoch - 630us/step
# Epoch 58/100
# 1532/1532 - 1s - loss: 0.0829 - accuracy: 0.9770 - val_loss: 0.1339 - val_accuracy: 0.9611 - 934ms/epoch - 609us/step
# Epoch 59/100
# 1532/1532 - 1s - loss: 0.0819 - accuracy: 0.9773 - val_loss: 0.1344 - val_accuracy: 0.9611 - 951ms/epoch - 621us/step
# Epoch 60/100
# 1532/1532 - 1s - loss: 0.0807 - accuracy: 0.9781 - val_loss: 0.1332 - val_accuracy: 0.9606 - 935ms/epoch - 610us/step
# Epoch 61/100
# 1532/1532 - 1s - loss: 0.0798 - accuracy: 0.9782 - val_loss: 0.1321 - val_accuracy: 0.9617 - 1s/epoch - 701us/step
# Epoch 62/100
# 1532/1532 - 1s - loss: 0.0790 - accuracy: 0.9784 - val_loss: 0.1316 - val_accuracy: 0.9612 - 1s/epoch - 707us/step
# Epoch 63/100
# 1532/1532 - 1s - loss: 0.0780 - accuracy: 0.9790 - val_loss: 0.1314 - val_accuracy: 0.9617 - 1s/epoch - 724us/step
# Epoch 64/100
# 1532/1532 - 1s - loss: 0.0772 - accuracy: 0.9789 - val_loss: 0.1319 - val_accuracy: 0.9609 - 1s/epoch - 715us/step
# Epoch 65/100
# 1532/1532 - 1s - loss: 0.0763 - accuracy: 0.9796 - val_loss: 0.1325 - val_accuracy: 0.9617 - 1s/epoch - 731us/step
# Epoch 66/100
# 1532/1532 - 1s - loss: 0.0755 - accuracy: 0.9794 - val_loss: 0.1312 - val_accuracy: 0.9611 - 1s/epoch - 759us/step
# Epoch 67/100
# 1532/1532 - 1s - loss: 0.0748 - accuracy: 0.9796 - val_loss: 0.1307 - val_accuracy: 0.9621 - 1s/epoch - 746us/step
# Epoch 68/100
# 1532/1532 - 1s - loss: 0.0739 - accuracy: 0.9802 - val_loss: 0.1291 - val_accuracy: 0.9624 - 1s/epoch - 723us/step
# Epoch 69/100
# 1532/1532 - 1s - loss: 0.0731 - accuracy: 0.9805 - val_loss: 0.1295 - val_accuracy: 0.9622 - 1s/epoch - 721us/step
# Epoch 70/100
# 1532/1532 - 1s - loss: 0.0722 - accuracy: 0.9803 - val_loss: 0.1294 - val_accuracy: 0.9623 - 1s/epoch - 712us/step
# Epoch 71/100
# 1532/1532 - 1s - loss: 0.0716 - accuracy: 0.9809 - val_loss: 0.1303 - val_accuracy: 0.9619 - 1s/epoch - 710us/step
# Epoch 72/100
# 1532/1532 - 1s - loss: 0.0708 - accuracy: 0.9810 - val_loss: 0.1294 - val_accuracy: 0.9631 - 1s/epoch - 715us/step
# Epoch 73/100
# 1532/1532 - 1s - loss: 0.0700 - accuracy: 0.9814 - val_loss: 0.1295 - val_accuracy: 0.9624 - 1s/epoch - 752us/step
# Epoch 74/100
# 1532/1532 - 1s - loss: 0.0695 - accuracy: 0.9817 - val_loss: 0.1292 - val_accuracy: 0.9626 - 1s/epoch - 723us/step
# Epoch 75/100
# 1532/1532 - 1s - loss: 0.0687 - accuracy: 0.9816 - val_loss: 0.1280 - val_accuracy: 0.9631 - 1s/epoch - 750us/step
# Epoch 76/100
# 1532/1532 - 1s - loss: 0.0680 - accuracy: 0.9818 - val_loss: 0.1294 - val_accuracy: 0.9623 - 1s/epoch - 726us/step
# Epoch 77/100
# 1532/1532 - 1s - loss: 0.0674 - accuracy: 0.9818 - val_loss: 0.1285 - val_accuracy: 0.9632 - 1s/epoch - 718us/step
# Epoch 78/100
# 1532/1532 - 1s - loss: 0.0667 - accuracy: 0.9817 - val_loss: 0.1283 - val_accuracy: 0.9624 - 1s/epoch - 711us/step
# Epoch 79/100
# 1532/1532 - 1s - loss: 0.0660 - accuracy: 0.9824 - val_loss: 0.1282 - val_accuracy: 0.9619 - 1s/epoch - 723us/step
# Epoch 80/100
# 1532/1532 - 1s - loss: 0.0653 - accuracy: 0.9826 - val_loss: 0.1285 - val_accuracy: 0.9628 - 1s/epoch - 745us/step
# Epoch 81/100
# 1532/1532 - 1s - loss: 0.0647 - accuracy: 0.9828 - val_loss: 0.1287 - val_accuracy: 0.9626 - 1s/epoch - 734us/step
# Epoch 82/100
# 1532/1532 - 1s - loss: 0.0641 - accuracy: 0.9831 - val_loss: 0.1284 - val_accuracy: 0.9637 - 1s/epoch - 722us/step
# Epoch 83/100
# 1532/1532 - 1s - loss: 0.0636 - accuracy: 0.9831 - val_loss: 0.1281 - val_accuracy: 0.9635 - 1s/epoch - 711us/step
# Epoch 84/100
# 1532/1532 - 1s - loss: 0.0628 - accuracy: 0.9833 - val_loss: 0.1269 - val_accuracy: 0.9631 - 1s/epoch - 708us/step
# Epoch 85/100
# 1532/1532 - 1s - loss: 0.0623 - accuracy: 0.9833 - val_loss: 0.1280 - val_accuracy: 0.9619 - 1s/epoch - 713us/step
# Epoch 86/100
# 1532/1532 - 1s - loss: 0.0617 - accuracy: 0.9836 - val_loss: 0.1273 - val_accuracy: 0.9632 - 1s/epoch - 722us/step
# Epoch 87/100
# 1532/1532 - 1s - loss: 0.0611 - accuracy: 0.9837 - val_loss: 0.1279 - val_accuracy: 0.9628 - 1s/epoch - 714us/step
# Epoch 88/100
# 1532/1532 - 1s - loss: 0.0605 - accuracy: 0.9838 - val_loss: 0.1277 - val_accuracy: 0.9626 - 1s/epoch - 723us/step
# Epoch 89/100
# 1532/1532 - 1s - loss: 0.0601 - accuracy: 0.9840 - val_loss: 0.1269 - val_accuracy: 0.9625 - 1s/epoch - 710us/step
# Epoch 90/100
# 1532/1532 - 1s - loss: 0.0596 - accuracy: 0.9843 - val_loss: 0.1271 - val_accuracy: 0.9645 - 1s/epoch - 708us/step
# Epoch 91/100
# 1532/1532 - 1s - loss: 0.0591 - accuracy: 0.9842 - val_loss: 0.1283 - val_accuracy: 0.9621 - 1s/epoch - 734us/step
# Epoch 92/100
# 1532/1532 - 1s - loss: 0.0585 - accuracy: 0.9848 - val_loss: 0.1270 - val_accuracy: 0.9628 - 1s/epoch - 716us/step
# Epoch 93/100
# 1532/1532 - 1s - loss: 0.0580 - accuracy: 0.9850 - val_loss: 0.1278 - val_accuracy: 0.9635 - 1s/epoch - 710us/step
# Epoch 94/100
# 1532/1532 - 1s - loss: 0.0575 - accuracy: 0.9845 - val_loss: 0.1281 - val_accuracy: 0.9639 - 1s/epoch - 756us/step
# Epoch 95/100
# 1532/1532 - 1s - loss: 0.0571 - accuracy: 0.9849 - val_loss: 0.1285 - val_accuracy: 0.9641 - 1s/epoch - 726us/step
# Epoch 96/100
# 1532/1532 - 1s - loss: 0.0565 - accuracy: 0.9852 - val_loss: 0.1272 - val_accuracy: 0.9646 - 1s/epoch - 716us/step
# Epoch 97/100
# 1532/1532 - 1s - loss: 0.0561 - accuracy: 0.9851 - val_loss: 0.1289 - val_accuracy: 0.9641 - 1s/epoch - 719us/step
# Epoch 98/100
# 1532/1532 - 1s - loss: 0.0555 - accuracy: 0.9853 - val_loss: 0.1268 - val_accuracy: 0.9648 - 1s/epoch - 715us/step
# Epoch 99/100
# 1532/1532 - 1s - loss: 0.0550 - accuracy: 0.9858 - val_loss: 0.1275 - val_accuracy: 0.9642 - 1s/epoch - 711us/step
# Epoch 100/100
# 1532/1532 - 1s - loss: 0.0545 - accuracy: 0.9862 - val_loss: 0.1279 - val_accuracy: 0.9632 - 1s/epoch - 710us/step

# %%
loss_train = history.history['loss']
loss_valid = history.history['val_loss']
accuracy_train = history.history['accuracy']
accuracy_train = np.reshape(accuracy_train, (M,1))
accuracy_valid = history.history['val_accuracy']
accuracy_valid = np.reshape(accuracy_valid, (M,1))


plt.figure(figsize=(10, 6))
epoch_list = np.arange(1, M+1)
plt.subplot(1, 2,  1)
plt.semilogy(epoch_list, loss_train, label = 'training_loss')
plt.semilogy(epoch_list, loss_valid, label = 'validation_loss')
plt.legend()
plt.xlabel('epoch')
plt.title('Loss')

plt.subplot(1, 2, 2)
plt.plot(epoch_list, accuracy_train*100, label = 'accuracy_loss')
plt.plot(epoch_list, accuracy_valid*100, label = 'accuracy_loss')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('%')
plt.title('Accuracy')
plt.tight_layout()
plt.show()

# %%
pred = model.predict(x_test)
pred = np.argmax(pred, 1)
accuracy = np.mean((pred==y_test).astype('int'))
accuracy
# Out:
# 0.9565776317668905
