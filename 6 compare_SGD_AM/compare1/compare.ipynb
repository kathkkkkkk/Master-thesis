# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('sgd_1.npz')
error_sgd = data['error_validation_list']
sb_sgd = data['SB_M1']
plt.semilogx(error_sgd, sb_sgd, '*', color = 'blue')

data = np.load('am_1.npz')
error_am = data['error_validation_list']
sb_am = data['SB_M1']
plt.semilogx(error_am, sb_am, '*', color = 'red')

# %%
plt.semilogx(error_sgd, sb_sgd, '*', color = 'blue')

data = np.load('am_2.npz')
error_am = data['error_validation_list']
sb_am = data['SB_M1']
plt.semilogx(error_am, sb_am, '*', color = 'red')

# %%
plt.semilogx(error_sgd, sb_sgd, '*', color = 'blue')

data = np.load('am_3.npz')
error_am = data['error_validation_list']
sb_am = data['SB_M1']
plt.semilogx(error_am, sb_am, '*', color = 'red')

# %%
plt.semilogx(error_sgd, sb_sgd, '*', color = 'blue')

data = np.load('am_4.npz')
error_am = data['error_validation_list']
sb_am = data['SB_M1']
plt.semilogx(error_am, sb_am, '*', color = 'red')
