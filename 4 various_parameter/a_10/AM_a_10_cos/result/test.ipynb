# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
data = np.load('am_9.npz')
error1 = data['error_train_list']

# %%
error2 = data['error_validation_list']

# %%
m = np.arange(1000)

plt.semilogy(m, error1)
plt.semilogy(m, error2)
