# %%
import numpy as np

# %%
data = np.load('sgd_34.npz')
data['error_train_list']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-3989f35203c1> in <module>
# ----> 1 data = np.load('sgd_34.npz')
#       2 data['error_train_list']
#
# d:\Anaconda\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sgd_34.npz'

# %%
data['error_validation_list']
# Out:
# array([0.34995383, 0.23215784, 0.21161181, 0.20341943, 0.19956237,
#        0.19741204, 0.19598335, 0.19488311, 0.19394853, 0.19311104,
#        0.19234184, 0.191629  , 0.19096769, 0.19035566, 0.1897913 ,
#        0.18927273, 0.18879756, 0.1883628 , 0.18796507, 0.1876007 ,
#        0.18726597, 0.18695722, 0.18667103, 0.18640426, 0.18615409,
#        0.18591807, 0.18569409, 0.18548034, 0.18527531, 0.18507774,
#        0.18488657, 0.18470092, 0.18452008, 0.18434342, 0.18417043,
#        0.18400069, 0.18383383, 0.18366951, 0.18350747, 0.18334745,
#        0.18318923, 0.1830326 , 0.1828774 , 0.18272344, 0.18257057,
#        0.18241864, 0.18226753, 0.1821171 , 0.18196723, 0.18181781,
#        0.18166873, 0.1815199 , 0.18137121, 0.18122258, 0.18107392,
#        0.18092514, 0.18077619, 0.18062697, 0.18047743, 0.1803275 ,
#        0.18017711, 0.18002622, 0.17987477, 0.1797227 , 0.17956998,
#        0.17941655, 0.17926238, 0.17910743, 0.17895166, 0.17879504,
# ...

# %%
data['SB_M1']
# Out:
# array([0.50243074, 0.89734429, 0.96381715, 0.98305989, 0.98933652,
#        0.99131509, 0.99185845, 0.99196303, 0.99196913, 0.99198241,
#        0.99202667, 0.99209938, 0.99219137, 0.99229343, 0.9923981 ,
#        0.99249994, 0.99259527, 0.99268179, 0.99275821, 0.99282398,
#        0.99287903, 0.99292355, 0.99295787, 0.99298241, 0.99299757,
#        0.99300373, 0.99300124, 0.99299041, 0.99297156, 0.99294498,
#        0.99291096, 0.99286979, 0.99282179, 0.99276729, 0.99270661,
#        0.99264011, 0.99256815, 0.99249109, 0.99240928, 0.99232309,
#        0.99223287, 0.99213897, 0.99204171, 0.99194143, 0.99183843,
#        0.99173301, 0.99162545, 0.991516  , 0.99140493, 0.99129247,
#        0.99117884, 0.99106426, 0.99094892, 0.99083302, 0.99071673,
#        0.99060022, 0.99048366, 0.99036719, 0.99025097, 0.99013513,
#        0.99001981, 0.98990513, 0.98979123, 0.98967821, 0.98956621,
#        0.98945532, 0.98934567, 0.98923735, 0.98913047, 0.98902514,
# ...
